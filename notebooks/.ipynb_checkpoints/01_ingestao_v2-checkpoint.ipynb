# %% [markdown]
# Inicialização do ambiente

# %%
#Import bibliotecas
import os
import sys
import time

from pyspark.sql import SparkSession
from pyspark.sql.functions import to_date, col, current_timestamp, from_json, lit, count, sum
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

# %%
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"

# %%
# !java -version
# Out:
# openjdk version "17.0.18" 2026-01-20
# OpenJDK Runtime Environment (build 17.0.18+8-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 17.0.18+8-Ubuntu-122.04.1, mixed mode, sharing)

# %%
#Iniciando sessão spark
spark = SparkSession.builder \
    .appName("bronze-layer") \
    .config("spark.jars.packages",
            "org.postgresql:postgresql:42.6.0,"
            "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.4.2") \
    .config("spark.sql.catalog.lakehouse", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.lakehouse.type", "hadoop") \
    .config("spark.sql.catalog.lakehouse.warehouse", "/tmp/warehouse") \
    .getOrCreate()
# Out:
# :: loading settings :: url = jar:file:/opt/conda/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/jovyan/.ivy2/cache
# The jars for the packages stored in: /home/jovyan/.ivy2/jars
# org.postgresql#postgresql added as a dependency
# org.apache.iceberg#iceberg-spark-runtime-3.5_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-45d3cead-e618-4f76-ae00-a564d98ab732;1.0
# 	confs: [default]
# 	found org.postgresql#postgresql;42.6.0 in central
# 	found org.checkerframework#checker-qual;3.31.0 in central
# 	found org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.4.2 in central
# :: resolution report :: resolve 551ms :: artifacts dl 13ms
# 	:: modules in use:
# 	org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.4.2 from central in [default]
# 	org.checkerframework#checker-qual;3.31.0 from central in [default]
# 	org.postgresql#postgresql;42.6.0 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-45d3cead-e618-4f76-ae00-a564d98ab732
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/12ms)
# 26/04/13 12:52:32 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
#Variaveis de conexao ao ambiente postgree
conexao = {
           "url": "jdbc:postgresql://postgres:5432/pipeline_transacoes",
           "user": "postgres",
           "password": "1234",
           "driver": "org.postgresql.Driver"
}

# %% [markdown]
# Processamento de dados

# %%
#Dados vindo da API
df_raw = spark.read.jdbc(
    url=conexao["url"],
    table="staging.transacoes_raw",  # tabela no PostgreSQL
    properties={
        "user": conexao["user"],
        "password": conexao["password"],
        "driver": conexao["driver"]
    }
)

df_raw.select("payload").show(truncate=True)
# Out:
# +--------------------+
# |             payload|
# +--------------------+
# |{"valor": 3999.49...|
# |{"valor": 1686.67...|
# |{"valor": 1881.22...|
# |{"valor": 2256.48...|
# |{"valor": 858.28,...|
# |{"valor": null, "...|
# |{"valor": 4626.87...|
# |{"valor": 3144.31...|
# |{"valor": 3534.2,...|
# |{"valor": 4452.82...|
# |{"valor": 864.84,...|
# |{"valor": 1865.53...|
# |{"valor": 1310.57...|
# |{"valor": 1271.79...|
# |{"valor": 2009.61...|
# |{"valor": 1310.57...|
# |{"valor": 1127.37...|
# |{"valor": 4453.29...|
# |{"valor": 4452.82...|
# |{"valor": 3947.14...|
# +--------------------+
# only showing top 20 rows

# %%
#Criando tabela bronze se não existir
spark.sql("CREATE DATABASE IF NOT EXISTS lakehouse.bronze")

#Definir schema do payload
schema_payload = StructType([
    StructField("valor", DoubleType(), True),
    StructField("produto", StringType(), True),
    StructField("categoria", StringType(), True),
    StructField("cliente_id", IntegerType(), True),
    StructField("quantidade", IntegerType(), True),
    StructField("metodo_pagamento", StringType(), True),
])

# Transformar DF raw
df_bronze = (
    df_raw
    .withColumn("data_ingestao", current_timestamp())
    .withColumn("data_particao", to_date(col("data_ingestao")))
    .withColumn("payload_struct", from_json(col("payload"), schema_payload))
    .select(
        "id",
        "payload_struct.*",
        "data_ingestao",
        "data_particao"
    )
)

# %%
print("DataFrame:")
df_bronze.groupBy("id").count().filter("count > 1").show()
# Out:
# DataFrame:
# [Stage 1:>                                                          (0 + 1) / 1]
# +---+-----+
# | id|count|
# +---+-----+
# +---+-----+

# %%
df_bronze.writeTo("lakehouse.bronze.transacoes") \
         .using("iceberg") \
         .partitionedBy("data_particao") \
         .append()

# %%
#Gravando no formato parquet
df_bronze.write.partitionBy("data_particao").mode("overwrite").parquet("/tmp/parquet_puro")

# Ler o Parquet gravado
df_parquet = spark.read.parquet("/tmp/parquet_puro")

# Medir tempo da query filtrando
start = time.time()
df_parquet_filtered = df_parquet.filter("data_particao = '2026-04-13'")
df_parquet_filtered.show()
print(f"Parquet puro - Tempo de execução: {time.time() - start} segundos")
# Out:
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# | id|  valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# |  1|3999.49|notebook|eletronicos|        29|         1|          boleto|2026-04-13 12:52:...|   2026-04-13|
# |  2|1686.67|camiseta|  vestuario|        60|         1|  cartao_credito|2026-04-13 12:52:...|   2026-04-13|
# |  3|1881.22|    fone|eletronicos|        45|         1|             pix|2026-04-13 12:52:...|   2026-04-13|
# |  4|2256.48|camiseta|  vestuario|       100|         2|          boleto|2026-04-13 12:52:...|   2026-04-13|
# |  5| 858.28|notebook|eletronicos|        48|         2|          boleto|2026-04-13 12:52:...|   2026-04-13|
# |  6|   NULL| celular|eletronicos|        92|         3|          boleto|2026-04-13 12:52:...|   2026-04-13|
# |  7|4626.87| celular|eletronicos|        51|         3|  cartao_credito|2026-04-13 12:52:...|   2026-04-13|
# |  8|3144.31|camiseta|  vestuario|        68|         1|          boleto|2026-04-13 12:52:...|   2026-04-13|
# |  9| 3534.2|camiseta|  vestuario|        88|         1|             pix|2026-04-13 12:52:...|   2026-04-13|
# | 10|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 12:52:...|   2026-04-13|
# | 11| 864.84|   tenis|  vestuario|        54|         3|          boleto|2026-04-13 12:52:...|   2026-04-13|
# | 12|1865.53|    fone|eletronicos|        10|         2|          boleto|2026-04-13 12:52:...|   2026-04-13|
# | 13|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 12:52:...|   2026-04-13|
# | 14|1271.79|notebook|eletronicos|        30|         1|  cartao_credito|2026-04-13 12:52:...|   2026-04-13|
# | 15|2009.61|    fone|eletronicos|        91|         3|          boleto|2026-04-13 12:52:...|   2026-04-13|
# | 16|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 12:52:...|   2026-04-13|
# | 17|1127.37|    fone|eletronicos|        98|         1|             pix|2026-04-13 12:52:...|   2026-04-13|
# | 18|4453.29|notebook|eletronicos|        76|         2|  cartao_credito|2026-04-13 12:52:...|   2026-04-13|
# | 19|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 12:52:...|   2026-04-13|
# | 20|3947.14|    fone|eletronicos|        35|         3|  cartao_credito|2026-04-13 12:52:...|   2026-04-13|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# only showing top 20 rows
#
# Parquet puro - Tempo de execução: 0.5342142581939697 segundos

# %%
start = time.time()
df_iceberg_filtered = spark.read.format("iceberg").load("lakehouse.bronze.transacoes").filter("data_particao='2026-04-13'")
df_iceberg_filtered.show()
print(f"Iceberg - Tempo de execução: {time.time() - start} segundos")
# Out:
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# | id|  valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# |  1|3999.49|notebook|eletronicos|        29|         1|          boleto|2026-04-13 02:49:...|   2026-04-13|
# |  2|1686.67|camiseta|  vestuario|        60|         1|  cartao_credito|2026-04-13 02:49:...|   2026-04-13|
# |  3|1881.22|    fone|eletronicos|        45|         1|             pix|2026-04-13 02:49:...|   2026-04-13|
# |  4|2256.48|camiseta|  vestuario|       100|         2|          boleto|2026-04-13 02:49:...|   2026-04-13|
# |  5| 858.28|notebook|eletronicos|        48|         2|          boleto|2026-04-13 02:49:...|   2026-04-13|
# |  6|   NULL| celular|eletronicos|        92|         3|          boleto|2026-04-13 02:49:...|   2026-04-13|
# |  7|4626.87| celular|eletronicos|        51|         3|  cartao_credito|2026-04-13 02:49:...|   2026-04-13|
# |  8|3144.31|camiseta|  vestuario|        68|         1|          boleto|2026-04-13 02:49:...|   2026-04-13|
# |  9| 3534.2|camiseta|  vestuario|        88|         1|             pix|2026-04-13 02:49:...|   2026-04-13|
# | 10|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 02:49:...|   2026-04-13|
# | 11| 864.84|   tenis|  vestuario|        54|         3|          boleto|2026-04-13 02:49:...|   2026-04-13|
# | 12|1865.53|    fone|eletronicos|        10|         2|          boleto|2026-04-13 02:49:...|   2026-04-13|
# | 13|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 02:49:...|   2026-04-13|
# | 14|1271.79|notebook|eletronicos|        30|         1|  cartao_credito|2026-04-13 02:49:...|   2026-04-13|
# | 15|2009.61|    fone|eletronicos|        91|         3|          boleto|2026-04-13 02:49:...|   2026-04-13|
# | 16|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 02:49:...|   2026-04-13|
# | 17|1127.37|    fone|eletronicos|        98|         1|             pix|2026-04-13 02:49:...|   2026-04-13|
# | 18|4453.29|notebook|eletronicos|        76|         2|  cartao_credito|2026-04-13 02:49:...|   2026-04-13|
# | 19|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 02:49:...|   2026-04-13|
# | 20|3947.14|    fone|eletronicos|        35|         3|  cartao_credito|2026-04-13 02:49:...|   2026-04-13|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# only showing top 20 rows
#
# Iceberg - Tempo de execução: 0.8955645561218262 segundos

# %%
#Select tabela transacoes na bronze
spark.sql("SELECT * FROM lakehouse.bronze.transacoes LIMIT 5").show()
# Out:
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# | id|  valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# |  1|3999.49|notebook|eletronicos|        29|         1|          boleto|2026-04-13 12:46:...|   2026-04-13|
# |  2|1686.67|camiseta|  vestuario|        60|         1|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|
# |  3|1881.22|    fone|eletronicos|        45|         1|             pix|2026-04-13 12:46:...|   2026-04-13|
# |  4|2256.48|camiseta|  vestuario|       100|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|
# |  5| 858.28|notebook|eletronicos|        48|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+

# %%
#Validando estrutura tabela bronze
spark.sql("Describe lakehouse.bronze.transacoes").show()
# Out:
# +--------------------+---------+-------+
# |            col_name|data_type|comment|
# +--------------------+---------+-------+
# |                  id|      int|   NULL|
# |               valor|   double|   NULL|
# |             produto|   string|   NULL|
# |           categoria|   string|   NULL|
# |          cliente_id|      int|   NULL|
# |          quantidade|      int|   NULL|
# |    metodo_pagamento|   string|   NULL|
# |       data_ingestao|timestamp|   NULL|
# |       data_particao|     date|   NULL|
# |# Partition Infor...|         |       |
# |          # col_name|data_type|comment|
# |       data_particao|     date|   NULL|
# +--------------------+---------+-------+

# %% [markdown]
# Validação dos dados (Bronze) para posteriormente realizar as transformações necessarias (Silver)

# %%
#Validando a existencia de dados nulos na bronze
df_bronze.select([
    sum(col(c).isNull().cast("int")).alias(c) 
    for c in df_bronze.columns
]).show()
# Out:
# +---+-----+-------+---------+----------+----------+----------------+-------------+-------------+
# | id|valor|produto|categoria|cliente_id|quantidade|metodo_pagamento|data_ingestao|data_particao|
# +---+-----+-------+---------+----------+----------+----------------+-------------+-------------+
# |  0|    6|      0|        0|         0|         0|               0|            0|            0|
# +---+-----+-------+---------+----------+----------+----------------+-------------+-------------+

# %%
#Verificando dados nulos no campo VALOR
spark.sql("SELECT * FROM lakehouse.bronze.transacoes where valor is null").show()
# Out:
# +---+-----+--------+-----------+----------+----------+----------------+--------------------+-------------+
# | id|valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|
# +---+-----+--------+-----------+----------+----------+----------------+--------------------+-------------+
# |  6| NULL| celular|eletronicos|        92|         3|          boleto|2026-04-13 02:49:...|   2026-04-13|
# | 23| NULL|camiseta|  vestuario|        50|         2|  cartao_credito|2026-04-13 02:49:...|   2026-04-13|
# | 33| NULL|camiseta|  vestuario|        95|         2|             pix|2026-04-13 02:49:...|   2026-04-13|
# | 46| NULL| celular|eletronicos|        44|         1|          boleto|2026-04-13 02:49:...|   2026-04-13|
# | 49| NULL| celular|eletronicos|        44|         1|          boleto|2026-04-13 02:49:...|   2026-04-13|
# | 59| NULL|   tenis|  vestuario|        37|         3|  cartao_credito|2026-04-13 02:49:...|   2026-04-13|
# |  6| NULL| celular|eletronicos|        92|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|
# | 23| NULL|camiseta|  vestuario|        50|         2|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|
# | 33| NULL|camiseta|  vestuario|        95|         2|             pix|2026-04-13 12:46:...|   2026-04-13|
# | 46| NULL| celular|eletronicos|        44|         1|          boleto|2026-04-13 12:46:...|   2026-04-13|
# | 49| NULL| celular|eletronicos|        44|         1|          boleto|2026-04-13 12:46:...|   2026-04-13|
# | 59| NULL|   tenis|  vestuario|        37|         3|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|
# |  6| NULL| celular|eletronicos|        92|         3|          boleto|2026-04-13 02:48:...|   2026-04-13|
# | 23| NULL|camiseta|  vestuario|        50|         2|  cartao_credito|2026-04-13 02:48:...|   2026-04-13|
# | 33| NULL|camiseta|  vestuario|        95|         2|             pix|2026-04-13 02:48:...|   2026-04-13|
# | 46| NULL| celular|eletronicos|        44|         1|          boleto|2026-04-13 02:48:...|   2026-04-13|
# | 49| NULL| celular|eletronicos|        44|         1|          boleto|2026-04-13 02:48:...|   2026-04-13|
# | 59| NULL|   tenis|  vestuario|        37|         3|  cartao_credito|2026-04-13 02:48:...|   2026-04-13|
# |  6| NULL| celular|eletronicos|        92|         3|          boleto|2026-04-13 03:04:...|   2026-04-13|
# | 23| NULL|camiseta|  vestuario|        50|         2|  cartao_credito|2026-04-13 03:04:...|   2026-04-13|
# +---+-----+--------+-----------+----------+----------+----------------+--------------------+-------------+
# only showing top 20 rows

# %%
#Validando se a duplicata para possivel tratamento
spark.sql("""
SELECT id, COUNT(*) as qtd
FROM lakehouse.bronze.transacoes
GROUP BY id
HAVING COUNT(*) > 1
""").show()
# Out:
# +---+---+
# | id|qtd|
# +---+---+
# | 31|  8|
# | 53|  8|
# | 34|  8|
# | 28|  8|
# | 26|  8|
# | 27|  8|
# | 44|  8|
# | 12|  8|
# | 22|  8|
# | 47|  8|
# |  1|  8|
# | 52|  8|
# | 13|  8|
# |  6|  8|
# | 16|  8|
# |  3|  8|
# | 20|  8|
# | 40|  8|
# | 57|  8|
# | 54|  8|
# +---+---+
# only showing top 20 rows

# %% [markdown]
# Transformação de Dados (Silver)

# %%
#Gerando tabela transacao SILVER com base na bronze porem com tratamento de campos null

# Ler Bronze
df_bronze = spark.read.table("lakehouse.bronze.transacoes")

#Tratamento valor null por 0
df_curated = (
    df_bronze.fillna({"valor": 0})
)

# Criar database Curated se não existir
spark.sql("CREATE DATABASE IF NOT EXISTS lakehouse.silver")

# Salvar Curated em Delta Lake, particionado por data
df_curated.writeTo("lakehouse.silver.transacoes") \
          .partitionedBy("data_particao") \
          .createOrReplace()


spark.sql("SELECT * FROM lakehouse.silver.transacoes").show()
# Out:
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# | id|  valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# |  1|3999.49|notebook|eletronicos|        29|         1|          boleto|2026-04-13 12:46:...|   2026-04-13|
# |  2|1686.67|camiseta|  vestuario|        60|         1|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|
# |  3|1881.22|    fone|eletronicos|        45|         1|             pix|2026-04-13 12:46:...|   2026-04-13|
# |  4|2256.48|camiseta|  vestuario|       100|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|
# |  5| 858.28|notebook|eletronicos|        48|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|
# |  6|    0.0| celular|eletronicos|        92|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|
# |  7|4626.87| celular|eletronicos|        51|         3|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|
# |  8|3144.31|camiseta|  vestuario|        68|         1|          boleto|2026-04-13 12:46:...|   2026-04-13|
# |  9| 3534.2|camiseta|  vestuario|        88|         1|             pix|2026-04-13 12:46:...|   2026-04-13|
# | 10|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|
# | 11| 864.84|   tenis|  vestuario|        54|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|
# | 12|1865.53|    fone|eletronicos|        10|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|
# | 13|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 12:46:...|   2026-04-13|
# | 14|1271.79|notebook|eletronicos|        30|         1|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|
# | 15|2009.61|    fone|eletronicos|        91|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|
# | 16|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 12:46:...|   2026-04-13|
# | 17|1127.37|    fone|eletronicos|        98|         1|             pix|2026-04-13 12:46:...|   2026-04-13|
# | 18|4453.29|notebook|eletronicos|        76|         2|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|
# | 19|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|
# | 20|3947.14|    fone|eletronicos|        35|         3|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# only showing top 20 rows

# %%
df_update = df_bronze.limit(5).withColumn('valor', col('valor')*1.1)
df_update.createOrReplaceTempView('staging_updates')

spark.sql('''
MERGE INTO lakehouse.silver.transacoes t
USING staging_updates s
ON t.id = s.id
WHEN MATCHED THEN UPDATE SET t.valor = s.valor, t.data_ingestao = current_timestamp()
WHEN NOT MATCHED THEN INSERT *
''')
# Out:
# DataFrame[]

# %%
#Atualização na tabela silver (ADD COLUMNS)
df_add = df_curated.withColumn("preco_unitario", (col("valor") / col("quantidade")))
df_add.writeTo("lakehouse.silver.transacoes") \
          .partitionedBy("data_particao") \
          .createOrReplace()

# %%
#Validando após alteração
spark.sql("SELECT * FROM lakehouse.silver.transacoes").show()
# Out:
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+------------------+
# | id|  valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|    preco_unitario|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+------------------+
# |  1|3999.49|notebook|eletronicos|        29|         1|          boleto|2026-04-13 12:46:...|   2026-04-13|           3999.49|
# |  2|1686.67|camiseta|  vestuario|        60|         1|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|           1686.67|
# |  3|1881.22|    fone|eletronicos|        45|         1|             pix|2026-04-13 12:46:...|   2026-04-13|           1881.22|
# |  4|2256.48|camiseta|  vestuario|       100|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|           1128.24|
# |  5| 858.28|notebook|eletronicos|        48|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|            429.14|
# |  6|    0.0| celular|eletronicos|        92|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|               0.0|
# |  7|4626.87| celular|eletronicos|        51|         3|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|           1542.29|
# |  8|3144.31|camiseta|  vestuario|        68|         1|          boleto|2026-04-13 12:46:...|   2026-04-13|           3144.31|
# |  9| 3534.2|camiseta|  vestuario|        88|         1|             pix|2026-04-13 12:46:...|   2026-04-13|            3534.2|
# | 10|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|1484.2733333333333|
# | 11| 864.84|   tenis|  vestuario|        54|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|288.28000000000003|
# | 12|1865.53|    fone|eletronicos|        10|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|           932.765|
# | 13|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 12:46:...|   2026-04-13|           655.285|
# | 14|1271.79|notebook|eletronicos|        30|         1|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|           1271.79|
# | 15|2009.61|    fone|eletronicos|        91|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|            669.87|
# | 16|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 12:46:...|   2026-04-13|           655.285|
# | 17|1127.37|    fone|eletronicos|        98|         1|             pix|2026-04-13 12:46:...|   2026-04-13|           1127.37|
# | 18|4453.29|notebook|eletronicos|        76|         2|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|          2226.645|
# | 19|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|1484.2733333333333|
# | 20|3947.14|    fone|eletronicos|        35|         3|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|1315.7133333333334|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+------------------+
# only showing top 20 rows

# %% [markdown]
# Analise de perfomance (snapshot)

# %%
spark.sql("""SELECT 
  snapshot_id,
  committed_at,
  operation,
  summary['operation-type'],
  summary['added-data-files'],
  summary['removed-data-files']
FROM lakehouse.silver.transacoes.snapshots
ORDER BY committed_at DESC""").show()
# Out:
# +-------------------+--------------------+---------+-----------------------+-------------------------+---------------------------+
# |        snapshot_id|        committed_at|operation|summary[operation-type]|summary[added-data-files]|summary[removed-data-files]|
# +-------------------+--------------------+---------+-----------------------+-------------------------+---------------------------+
# |5120946730569197697|2026-04-13 12:52:...|   append|                   NULL|                        1|                       NULL|
# |3028353755201704544|2026-04-13 12:52:...|overwrite|                   NULL|                        1|                       NULL|
# |7849690985131657991|2026-04-13 12:52:...|   append|                   NULL|                        1|                       NULL|
# |3627596067695198851|2026-04-13 12:52:...|   delete|                   NULL|                     NULL|                       NULL|
# | 913469508766420102|2026-04-13 12:46:...|overwrite|                   NULL|                        1|                       NULL|
# |2226461031760001634|2026-04-13 12:46:...|   append|                   NULL|                        1|                       NULL|
# |7628520226029479646|2026-04-13 12:46:...|overwrite|                   NULL|                        1|                       NULL|
# |1915552410171583597|2026-04-13 12:46:...|   append|                   NULL|                        1|                       NULL|
# |1861293661976704301|2026-04-13 03:06:...|overwrite|                   NULL|                        1|                       NULL|
# |3614688107237672550|2026-04-13 03:06:...|   append|                   NULL|                        1|                       NULL|
# |4049556779173583653|2026-04-13 03:06:...|overwrite|                   NULL|                        1|                       NULL|
# |2857353421903179058|2026-04-13 03:06:...|   append|                   NULL|                        1|                       NULL|
# |8714268096933929523|2026-04-13 03:05:...|   delete|                   NULL|                     NULL|                       NULL|
# |7320393716753267252|2026-04-13 03:04:...|overwrite|                   NULL|                        1|                       NULL|
# |5885757586304150631|2026-04-13 03:04:...|   append|                   NULL|                        1|                       NULL|
# |6218671939599915813|2026-04-13 03:04:...|overwrite|                   NULL|                        1|                       NULL|
# |8618461278109176958|2026-04-13 03:04:...|   append|                   NULL|                        1|                       NULL|
# |5053697107681229730|2026-04-13 03:03:...|   append|                   NULL|                        1|                       NULL|
# +-------------------+--------------------+---------+-----------------------+-------------------------+---------------------------+

# %% [markdown]
# Com base na analise de snapshot da tabela silver podemos notar que só foi feito append, ou seja, só houve adição de dados
# nenhum arquivo foi removido ou reescrito. O append é uma operação de baixo custo, pois não há custo de reescrita.
# No nosso cenario é gerado novos dados já com a coluna calculada e inseridos na tabela, gerandoa alerta de perfomance somente relacionado a small files.

# %%
antes = spark.sql("""
SELECT COUNT(*) as total 
FROM lakehouse.silver.transacoes 
WHERE valor = 0.0
""").collect()[0]["total"]

spark.sql("""
DELETE FROM lakehouse.silver.transacoes 
WHERE valor = 0.0
""")

depois = spark.sql("""
SELECT COUNT(*) as total 
FROM lakehouse.silver.transacoes 
WHERE valor = 0.0
""").collect()[0]["total"]

print(f"Deletados: {antes - depois}")
# Out:
# Deletados: 48

# %%
spark.sql("SELECT snapshot_id, committed_at FROM lakehouse.silver.transacoes.snapshots ORDER BY committed_at DESC").show()
# Out:
# +-------------------+--------------------+
# |        snapshot_id|        committed_at|
# +-------------------+--------------------+
# |4441256124157884351|2026-04-13 12:52:...|
# |5120946730569197697|2026-04-13 12:52:...|
# |3028353755201704544|2026-04-13 12:52:...|
# |7849690985131657991|2026-04-13 12:52:...|
# |3627596067695198851|2026-04-13 12:52:...|
# | 913469508766420102|2026-04-13 12:46:...|
# |2226461031760001634|2026-04-13 12:46:...|
# |7628520226029479646|2026-04-13 12:46:...|
# |1915552410171583597|2026-04-13 12:46:...|
# |1861293661976704301|2026-04-13 03:06:...|
# |3614688107237672550|2026-04-13 03:06:...|
# |4049556779173583653|2026-04-13 03:06:...|
# |2857353421903179058|2026-04-13 03:06:...|
# |8714268096933929523|2026-04-13 03:05:...|
# |7320393716753267252|2026-04-13 03:04:...|
# |5885757586304150631|2026-04-13 03:04:...|
# |6218671939599915813|2026-04-13 03:04:...|
# |8618461278109176958|2026-04-13 03:04:...|
# |5053697107681229730|2026-04-13 03:03:...|
# +-------------------+--------------------+

# %%
spark.sql("SELECT * FROM lakehouse.silver.transacoes VERSION AS OF 913469508766420102").show()
# Out:
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+------------------+
# | id|  valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|    preco_unitario|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+------------------+
# |  1|3999.49|notebook|eletronicos|        29|         1|          boleto|2026-04-13 12:46:...|   2026-04-13|           3999.49|
# |  2|1686.67|camiseta|  vestuario|        60|         1|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|           1686.67|
# |  3|1881.22|    fone|eletronicos|        45|         1|             pix|2026-04-13 12:46:...|   2026-04-13|           1881.22|
# |  4|2256.48|camiseta|  vestuario|       100|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|           1128.24|
# |  5| 858.28|notebook|eletronicos|        48|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|            429.14|
# |  7|4626.87| celular|eletronicos|        51|         3|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|           1542.29|
# |  8|3144.31|camiseta|  vestuario|        68|         1|          boleto|2026-04-13 12:46:...|   2026-04-13|           3144.31|
# |  9| 3534.2|camiseta|  vestuario|        88|         1|             pix|2026-04-13 12:46:...|   2026-04-13|            3534.2|
# | 10|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|1484.2733333333333|
# | 11| 864.84|   tenis|  vestuario|        54|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|288.28000000000003|
# | 12|1865.53|    fone|eletronicos|        10|         2|          boleto|2026-04-13 12:46:...|   2026-04-13|           932.765|
# | 13|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 12:46:...|   2026-04-13|           655.285|
# | 14|1271.79|notebook|eletronicos|        30|         1|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|           1271.79|
# | 15|2009.61|    fone|eletronicos|        91|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|            669.87|
# | 16|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 12:46:...|   2026-04-13|           655.285|
# | 17|1127.37|    fone|eletronicos|        98|         1|             pix|2026-04-13 12:46:...|   2026-04-13|           1127.37|
# | 18|4453.29|notebook|eletronicos|        76|         2|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|          2226.645|
# | 19|4452.82|   tenis|  vestuario|        94|         3|          boleto|2026-04-13 12:46:...|   2026-04-13|1484.2733333333333|
# | 20|3947.14|    fone|eletronicos|        35|         3|  cartao_credito|2026-04-13 12:46:...|   2026-04-13|1315.7133333333334|
# | 21|1310.57|   tenis|  vestuario|        92|         2|             pix|2026-04-13 12:46:...|   2026-04-13|           655.285|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+------------------+
# only showing top 20 rows

# %%
def benchmark(nome, func):
    start = time.time()
    func()
    tempo = time.time() - start
    print(f"{nome}: {tempo:.4f} segundos")
    return tempo

parquet_time = benchmark('Parquet', lambda: spark.read.parquet('/tmp/parquet_puro').count())
iceberg_time = benchmark('Iceberg', lambda: spark.table('lakehouse.silver.transacoes').count())

print('Comparativo final:', parquet_time, iceberg_time)
# Out:
# Parquet: 0.5117 segundos
# Iceberg: 0.4145 segundos
# Comparativo final: 0.5116708278656006 0.414501428604126

# %%
# !ls /tmp/warehouse/bronze/transacoes
# Out:
# data  metadata
