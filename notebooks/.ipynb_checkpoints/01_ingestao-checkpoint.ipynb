# %%
#Import bibliotecas
import os
import sys

from pyspark.sql import SparkSession
from pyspark.sql.functions import to_date, count, col, current_timestamp, from_json, lit
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

# %%
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"

# %%
# !java -version
# Out:
# openjdk version "17.0.18" 2026-01-20
# OpenJDK Runtime Environment (build 17.0.18+8-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 17.0.18+8-Ubuntu-122.04.1, mixed mode, sharing)

# %%
#Iniciando sessão spark
spark = SparkSession.builder \
    .appName("bronze-layer") \
    .config("spark.jars.packages",
            "org.postgresql:postgresql:42.6.0,"
            "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.4.2") \
    .config("spark.sql.catalog.lakehouse", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.lakehouse.type", "hadoop") \
    .config("spark.sql.catalog.lakehouse.warehouse", "/tmp/warehouse") \
    .getOrCreate()

# %%
# !ls /tmp/warehouse/bronze/transacoes
# Out:
# data  metadata

# %%
#Variaveis de conexao ao ambiente postgree
conexao = {
           "url": "jdbc:postgresql://postgres:5432/pipeline_transacoes",
           "user": "postgres",
           "password": "1234",
           "driver": "org.postgresql.Driver"
}

# %%
#Dados vindo da API
df_raw = spark.read.jdbc(
    url=conexao["url"],
    table="staging.transacoes_raw",  # tabela no PostgreSQL
    properties={
        "user": conexao["user"],
        "password": conexao["password"],
        "driver": conexao["driver"]
    }
)

df_raw.select("payload").show(truncate=True)
# Out:
# +--------------------+
# |             payload|
# +--------------------+
# |{"valor": 2437.22...|
# |{"valor": 775.25,...|
# |{"valor": 528.18,...|
# |{"valor": 2253.03...|
# |{"valor": null, "...|
# |{"valor": 1942.65...|
# |{"valor": 3931.11...|
# |{"valor": 2090.21...|
# |{"valor": 4579.7,...|
# |{"valor": 4995.86...|
# |{"valor": 1422.14...|
# |{"valor": 4902.43...|
# |{"valor": 1797.08...|
# |{"valor": 1114.42...|
# |{"valor": 2306.02...|
# |{"valor": 2266.53...|
# |{"valor": 1972.3,...|
# |{"valor": 54.76, ...|
# |{"valor": null, "...|
# |{"valor": 3382.19...|
# +--------------------+
# only showing top 20 rows

# %%
#Criando tabela bronze se não existir
spark.sql("CREATE DATABASE IF NOT EXISTS lakehouse.bronze")

#Definir schema do payload
schema_payload = StructType([
    StructField("valor", DoubleType(), True),
    StructField("produto", StringType(), True),
    StructField("categoria", StringType(), True),
    StructField("cliente_id", IntegerType(), True),
    StructField("quantidade", IntegerType(), True),
    StructField("metodo_pagamento", StringType(), True),
])

# Transformar DF raw
df_bronze = (
    df_raw
    .withColumn("data_ingestao", current_timestamp())
    .withColumn("data_particao", to_date(col("data_ingestao")))
    .withColumn("payload_struct", from_json(col("payload"), schema_payload))
    .select(
        "id",
        "payload_struct.*",
        "data_ingestao",
        "data_particao"
    )
)                           
df_bronze.writeTo("lakehouse.bronze.transacoes") \
         .using("iceberg") \
         .partitionedBy("data_particao") \
         .createOrReplace()

# %%
#Select tabela transacoes na bronze
spark.sql("SELECT * FROM lakehouse.bronze.transacoes LIMIT 5").show()
# Out:
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# | id|  valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# |  1|2437.22|notebook|eletronicos|        67|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|
# |  2| 775.25|    fone|eletronicos|        50|         3|             pix|2026-04-12 15:47:...|   2026-04-12|
# |  3| 528.18| celular|eletronicos|         1|         3|             pix|2026-04-12 15:47:...|   2026-04-12|
# |  4|2253.03| celular|eletronicos|        53|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|
# |  5|   NULL|notebook|eletronicos|        76|         3|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+

# %%
#Validando estrutura tabela bronze
spark.sql("Describe lakehouse.bronze.transacoes").show()
# Out:
# +--------------------+---------+-------+
# |            col_name|data_type|comment|
# +--------------------+---------+-------+
# |                  id|      int|   NULL|
# |               valor|   double|   NULL|
# |             produto|   string|   NULL|
# |           categoria|   string|   NULL|
# |          cliente_id|      int|   NULL|
# |          quantidade|      int|   NULL|
# |    metodo_pagamento|   string|   NULL|
# |       data_ingestao|timestamp|   NULL|
# |       data_particao|     date|   NULL|
# |# Partition Infor...|         |       |
# |          # col_name|data_type|comment|
# |       data_particao|     date|   NULL|
# +--------------------+---------+-------+

# %%
#Validando a existencia de dados nulos na bronze
from pyspark.sql.functions import col, sum
df_bronze.select([
    sum(col(c).isNull().cast("int")).alias(c) 
    for c in df_bronze.columns
]).show()
# Out:
# +---+-----+-------+---------+----------+----------+----------------+-------------+-------------+
# | id|valor|produto|categoria|cliente_id|quantidade|metodo_pagamento|data_ingestao|data_particao|
# +---+-----+-------+---------+----------+----------+----------------+-------------+-------------+
# |  0|   10|      0|        0|         0|         0|               0|            0|            0|
# +---+-----+-------+---------+----------+----------+----------------+-------------+-------------+

# %%
#Verificando dados nulos no campo VALOR
spark.sql("SELECT * FROM lakehouse.bronze.transacoes where valor is null").show()
# Out:
# +---+-----+--------+-----------+----------+----------+----------------+--------------------+-------------+
# | id|valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|
# +---+-----+--------+-----------+----------+----------+----------------+--------------------+-------------+
# |  5| NULL|notebook|eletronicos|        76|         3|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|
# | 19| NULL|    fone|eletronicos|        74|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|
# | 23| NULL|notebook|eletronicos|         6|         1|             pix|2026-04-12 15:47:...|   2026-04-12|
# | 27| NULL|camiseta|  vestuario|        32|         1|          boleto|2026-04-12 15:47:...|   2026-04-12|
# | 31| NULL| celular|eletronicos|        16|         3|             pix|2026-04-12 15:47:...|   2026-04-12|
# | 36| NULL|notebook|eletronicos|        97|         1|          boleto|2026-04-12 15:47:...|   2026-04-12|
# | 40| NULL| celular|eletronicos|        58|         3|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|
# | 41| NULL| celular|eletronicos|        17|         1|             pix|2026-04-12 15:47:...|   2026-04-12|
# | 49| NULL|   tenis|  vestuario|        84|         2|             pix|2026-04-12 15:47:...|   2026-04-12|
# | 50| NULL|camiseta|  vestuario|        73|         3|          boleto|2026-04-12 15:47:...|   2026-04-12|
# +---+-----+--------+-----------+----------+----------+----------------+--------------------+-------------+

# %%
#Validando se a duplicata para possivel tratamento
df_bronze.groupBy("id", "data_ingestao") \
         .agg(count("*").alias("qtd")) \
         .filter(col("qtd") > 1) \
         .show()
# Out:
# +---+-------------+---+
# | id|data_ingestao|qtd|
# +---+-------------+---+
# +---+-------------+---+

# %%
#Gerando tabela transacao SILVER com base na bronze porem com tratamento de campos null

# Ler Bronze
df_bronze = spark.read.table("lakehouse.bronze.transacoes")

#Tratamento valor null por 0
df_curated = (
    df_bronze.fillna({"valor": 0})
)

# Criar database Curated se não existir
spark.sql("CREATE DATABASE IF NOT EXISTS lakehouse.silver")

# Salvar Curated em Delta Lake, particionado por data
df_curated.writeTo("lakehouse.silver.transacoes") \
          .partitionedBy("data_particao") \
          .createOrReplace()


spark.sql("SELECT * FROM lakehouse.silver.transacoes").show()
# Out:
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# | id|  valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# |  1|2437.22|notebook|eletronicos|        67|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|
# |  2| 775.25|    fone|eletronicos|        50|         3|             pix|2026-04-12 15:47:...|   2026-04-12|
# |  3| 528.18| celular|eletronicos|         1|         3|             pix|2026-04-12 15:47:...|   2026-04-12|
# |  4|2253.03| celular|eletronicos|        53|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|
# |  5|    0.0|notebook|eletronicos|        76|         3|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|
# |  6|1942.65|notebook|eletronicos|        15|         1|             pix|2026-04-12 15:47:...|   2026-04-12|
# |  7|3931.11|notebook|eletronicos|         2|         2|             pix|2026-04-12 15:47:...|   2026-04-12|
# |  8|2090.21|    fone|eletronicos|        89|         1|             pix|2026-04-12 15:47:...|   2026-04-12|
# |  9| 4579.7|   tenis|  vestuario|        27|         2|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|
# | 10|4995.86| celular|eletronicos|        88|         3|          boleto|2026-04-12 15:47:...|   2026-04-12|
# | 11|1422.14|    fone|eletronicos|        84|         1|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|
# | 12|4902.43|   tenis|  vestuario|        13|         3|          boleto|2026-04-12 15:47:...|   2026-04-12|
# | 13|1797.08|notebook|eletronicos|        22|         2|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|
# | 14|1114.42|   tenis|  vestuario|        84|         1|          boleto|2026-04-12 15:47:...|   2026-04-12|
# | 15|2306.02| celular|eletronicos|        55|         1|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|
# | 16|2266.53|camiseta|  vestuario|        68|         2|             pix|2026-04-12 15:47:...|   2026-04-12|
# | 17| 1972.3|camiseta|  vestuario|        46|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|
# | 18|  54.76|   tenis|  vestuario|        95|         1|          boleto|2026-04-12 15:47:...|   2026-04-12|
# | 19|    0.0|    fone|eletronicos|        74|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|
# | 20|3382.19|    fone|eletronicos|        23|         3|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+
# only showing top 20 rows

# %%
#Atualização na tabela silver (ADD COLUMNS)
df_add = df_curated.withColumn("preco_unitario", (col("valor") / col("quantidade")))
df_add.writeTo("lakehouse.silver.transacoes") \
          .partitionedBy("data_particao") \
          .createOrReplace()

# %%
#Validando após alteração
spark.sql("SELECT * FROM lakehouse.silver.transacoes").show()
# Out:
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+------------------+
# | id|  valor| produto|  categoria|cliente_id|quantidade|metodo_pagamento|       data_ingestao|data_particao|    preco_unitario|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+------------------+
# |  1|2437.22|notebook|eletronicos|        67|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|           1218.61|
# |  2| 775.25|    fone|eletronicos|        50|         3|             pix|2026-04-12 15:47:...|   2026-04-12| 258.4166666666667|
# |  3| 528.18| celular|eletronicos|         1|         3|             pix|2026-04-12 15:47:...|   2026-04-12|176.05999999999997|
# |  4|2253.03| celular|eletronicos|        53|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|          1126.515|
# |  5|    0.0|notebook|eletronicos|        76|         3|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|               0.0|
# |  6|1942.65|notebook|eletronicos|        15|         1|             pix|2026-04-12 15:47:...|   2026-04-12|           1942.65|
# |  7|3931.11|notebook|eletronicos|         2|         2|             pix|2026-04-12 15:47:...|   2026-04-12|          1965.555|
# |  8|2090.21|    fone|eletronicos|        89|         1|             pix|2026-04-12 15:47:...|   2026-04-12|           2090.21|
# |  9| 4579.7|   tenis|  vestuario|        27|         2|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|           2289.85|
# | 10|4995.86| celular|eletronicos|        88|         3|          boleto|2026-04-12 15:47:...|   2026-04-12|1665.2866666666666|
# | 11|1422.14|    fone|eletronicos|        84|         1|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|           1422.14|
# | 12|4902.43|   tenis|  vestuario|        13|         3|          boleto|2026-04-12 15:47:...|   2026-04-12|1634.1433333333334|
# | 13|1797.08|notebook|eletronicos|        22|         2|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|            898.54|
# | 14|1114.42|   tenis|  vestuario|        84|         1|          boleto|2026-04-12 15:47:...|   2026-04-12|           1114.42|
# | 15|2306.02| celular|eletronicos|        55|         1|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|           2306.02|
# | 16|2266.53|camiseta|  vestuario|        68|         2|             pix|2026-04-12 15:47:...|   2026-04-12|          1133.265|
# | 17| 1972.3|camiseta|  vestuario|        46|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|            986.15|
# | 18|  54.76|   tenis|  vestuario|        95|         1|          boleto|2026-04-12 15:47:...|   2026-04-12|             54.76|
# | 19|    0.0|    fone|eletronicos|        74|         2|          boleto|2026-04-12 15:47:...|   2026-04-12|               0.0|
# | 20|3382.19|    fone|eletronicos|        23|         3|  cartao_credito|2026-04-12 15:47:...|   2026-04-12|1127.3966666666668|
# +---+-------+--------+-----------+----------+----------+----------------+--------------------+-------------+------------------+
# only showing top 20 rows
